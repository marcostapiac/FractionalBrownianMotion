# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import os
import matplotlib.pyplot as plt
from configs.RecursiveVPSDE.Markovian_fBiPot.recursive_Markovian_PostMeanScore_fBiPot_LowFTh_T256_H05_tl_110data_StbleTgt import get_config
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
config = get_config()
num_paths = 1024 if config.feat_thresh == 1. else 10240
assert num_paths == 1024
root_dir = "/Users/marcos/Library/CloudStorage/OneDrive-ImperialCollegeLondon/StatML_CDT/Year2/DiffusionModels/"

# %%
import pandas as pd
def get_drift_files_nonfull(config, root_dir ):
    ts_type = f"BiPot"
    include = (f"_{num_paths}NPaths_{config.t0}t0_{config.deltaT:.3e}dT_").replace(".", "")
    root_nadaraya_dir = root_dir + f"ExperimentResults/Nadaraya/BiPotLessData/"
    true_files = []
    local_files = []
    mses = []
    for file in os.listdir(root_nadaraya_dir):
        if "IIDNadaraya" in file and ts_type in file and include in file:
            if "true" in file:
                true_files.append(root_nadaraya_dir+file)
            elif "global" in file:
                local_files.append(root_nadaraya_dir+file)
            elif "MSEs" not in file and "bwidx" in file:
                mses_full = pd.read_parquet(root_nadaraya_dir+file)
                print(file)
                mses.append(mses_full)
    mses = pd.concat(mses).sort_values("bw", axis=0)
    assert len(true_files)>0, "No true files found"
    assert len(local_files)>0, "No local files found"
    assert (len(true_files) == len(local_files))
    def extract_bw_number(s):
        match = s.split("/")[-1].split("_")[3][:-2]
        return float("0." + match)
    true_files = sorted(true_files, key=extract_bw_number)
    local_files = sorted(local_files, key=extract_bw_number)
    bws = [extract_bw_number(f) for f in true_files]
    return true_files, local_files, bws, mses

# %%
config = get_config()
true_files, local_files, bws, mses = get_drift_files_nonfull(config=config, root_dir=root_dir)
fig, ax = plt.subplots(figsize=(14,9))
print(mses)
mses.plot(kind="scatter", x="bw", y="mse", ax=ax, s=100)
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_ylabel("MSE")
ax.set_xlabel("Kernel Bandwidth")
ax.set_title(f"Minimum MSE is {mses.iloc[np.argmin(mses.mse), 1], np.argmin(mses.mse)}")
# Out:
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0000857bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx4.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_1135011bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx30.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_7852356bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx38.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0024046bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx16.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0073079bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx20.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0003437bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx9.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0000491bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx2.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_630957344bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx53.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_4841724bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx36.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_100000bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx59.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0001972bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx7.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_2985383bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx34.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0001493bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx6.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0010446bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx13.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_25118864bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx43.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_398107171bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx52.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_10000bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx54.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_616595bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx37.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_1840772bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx32.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_144544bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx31.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0222102bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx24.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_31622777bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx44.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_3801894bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx35.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_158489319bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx50.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0002603bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx8.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0055348bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx19.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_79432823bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx48.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0127401bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx22.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_009649bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx21.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0511235bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx27.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_15848932bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx41.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0293252bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx25.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0007912bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx12.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0005992bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx11.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0000372bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx1.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0168214bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx23.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0387196bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx26.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0001131bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx5.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_6309573445bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx58.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0013793bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx14.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_3981071706bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx57.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0891251bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx29.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0000649bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx3.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_12589254bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx40.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_251188643bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx51.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_19952623bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx42.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0031749bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx17.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_1584893192bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx55.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_100bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx39.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0000282bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx0.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0004538bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx10.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_63095734bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx47.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_1000bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx49.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_50118723bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx46.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0041919bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx18.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_39810717bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx45.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_2511886432bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx56.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_067501bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx28.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_0018211bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx15.pickle
# IIDNadarayaGPU_fBiPot_DriftEvalExp_2344229bw_1024NPaths_00t0_3906e-03dT_025a_-05b_00c_muhats_MSE_bwidx33.pickle
#               bw       mse
# 0       0.000282  6.122053
# 1       0.000372  3.884928
# 2       0.000491  2.655174
# 3       0.000649  1.916033
# 4       0.000857  1.440273
# 5       0.001131  1.090439
# 6       0.001493  0.823629
# 7       0.001972  0.633810
# 8       0.002603  0.490705
# 9       0.003437  0.380332
# 10      0.004538  0.294004
# 11      0.005992  0.227880
# 12      0.007912  0.177661
# 13      0.010446  0.137068
# 14      0.013793  0.102574
# 15      0.018211  0.074034
# 16      0.024046  0.051928
# 17      0.031749  0.035929
# 18      0.041919  0.025193
# 19      0.055348  0.018419
# 20      0.073079  0.013893
# 21      0.096490  0.011372
# 22      0.127401  0.012703
# 23      0.168214  0.022020
# 24      0.222102  0.045098
# 25      0.293252  0.086327
# 26      0.387196  0.145831
# 27      0.511235  0.215740
# 28      0.675010  0.276666
# 29      0.891251  0.312685
# 30      1.135011  0.326594
# 31      1.445440  0.332657
# 32      1.840772  0.335897
# 33      2.344229  0.338097
# 34      2.985383  0.339699
# 35      3.801894  0.340834
# 36      4.841724  0.341605
# 37      6.165950  0.342112
# 38      7.852356  0.342437
# 39     10.000000  0.342643
# 40     12.589254  0.342767
# 41     15.848932  0.342846
# 42     19.952623  0.342896
# 43     25.118864  0.342928
# 44     31.622777  0.342948
# 45     39.810717  0.342961
# 46     50.118723  0.342969
# 47     63.095734  0.342974
# 48     79.432823  0.342977
# 49    100.000000  0.342979
# 50    158.489319  0.342981
# 51    251.188643  0.342982
# 52    398.107171  0.342983
# 53    630.957344  0.342983
# 54   1000.000000  0.342983
# 55   1584.893192  0.342983
# 56   2511.886432  0.342983
# 57   3981.071706  0.342983
# 58   6309.573445  0.342983
# 59  10000.000000  0.342983
# Text(0.5, 1.0, 'Minimum MSE is (0.011371946, 21)')

# %%
fig, ax = plt.subplots(figsize=(14,9))
mses.plot(kind="scatter", x="bw", y="mse", ax=ax, s=100)
ax.set_xscale("log")
ax.set_ylabel("MSE")
ax.set_xlabel("Kernel Bandwidth")
ax.set_title(f"Minimum MSE is {mses.iloc[np.argmin(mses.mse), 1], np.argmin(mses.mse)}")
# Out:
# Text(0.5, 1.0, 'Minimum MSE is (0.011371946, 21)')

# %%
curr_rmse = np.inf
toSave = False
i = 0
for file in zip(*[true_files, local_files, bws]):
    bw = file[-1]
    all_true_states = np.load(file[0])
    all_local_states = np.load(file[1])
    if all_local_states.shape[0] != 2: continue
    if (len(all_true_states.shape) == len(all_local_states.shape) == 4):
        time_steps = np.linspace(config.t0,config.deltaT*all_true_states.shape[2],all_true_states.shape[2])
        all_global_errors = np.sum(np.power(all_true_states- all_local_states,2), axis=-1)
        all_global_errors=all_global_errors.reshape(-1, all_global_errors.shape[-1])            # (K, N, T)
        total_local_errors = np.sqrt(np.nanmean(all_global_errors, axis=(0)))/np.sqrt(time_steps)
        all_paths_err = np.sqrt(all_global_errors)/np.sqrt(time_steps)
        total_local_errors[total_local_errors==np.inf] = 0.
        all_paths_err[all_paths_err==np.inf] = 0.
        total_local_errors_minq, total_local_errors_maxq  = np.quantile(all_paths_err, q=[0.005, 0.995], axis=0) # (T,)
        print(total_local_errors[-1], bw, curr_rmse)
        i += 1
        if total_local_errors[-1]  < curr_rmse:
            curr_rmse = total_local_errors[-1]
            fig, ax = plt.subplots(figsize=(14,9))
            plt.grid(True)
            ax.scatter(time_steps, total_local_errors)
            plt.fill_between(time_steps,y1=total_local_errors_minq, y2=total_local_errors_maxq, color="blue", alpha=0.4)
            ax.set_title(rf"Pathwise RMSE for Nadaraya Estimator for $\mu_5$",fontsize=40)
            ax.set_ylabel("MSE", fontsize=38)
            ax.set_xlabel("Time Axis", fontsize=38)
            ax.tick_params(labelsize=38)
            plt.tight_layout()
            if toSave:
                plt.savefig((root_dir + f"DiffusionModelPresentationImages/IIDNadaraya/BiPotLessData/IIDNadaraya_{config.ndims}DLnz_DriftTrack_{round(bw, 6)}bw_{config.forcing_const}FConst_{config.forcing_const}FConst_{round(total_local_errors_minq[-1], 8)}_MinIQR_{round(total_local_errors[-1], 8)}MeanIQR_{round(total_local_errors_maxq[-1], 8)}_MaxIQR").replace(".", "")+".png")
            plt.show()
            plt.close()
            print(f"Final time cumulative MSE local-time error {total_local_errors[-1]} with IQR ({total_local_errors_minq[-1], total_local_errors_maxq[-1]})at bw {bw} for {config.forcing_const}FConst\n")

# %%
from utils.resource_logger import wallclock_and_system_metrics
data = wallclock_and_system_metrics(config.nadaraya_resource_logging_path, inclusive=False)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 2
#       1 from utils.resource_logger import wallclock_and_system_metrics
# ----> 2 data = wallclock_and_system_metrics(config.nadaraya_resource_logging_path, inclusive=False)
#       3 data
#
# File ~/GitHubRepos/FractionalBrownianMotion/utils/resource_logger.py:356, in wallclock_and_system_metrics(run_json_or_path, inclusive)
#     355 def wallclock_and_system_metrics(run_json_or_path, inclusive=False):
# --> 356     r = _load(run_json_or_path)
#     358     # total wall-clock [h]
#     359     wall_s = r.get("wall_clock_sec") or (float(r["end_time"]) - float(r["start_time"]))
#
# File ~/GitHubRepos/FractionalBrownianMotion/utils/resource_logger.py:350, in _load(run)
#     348 def _load(run):
#     349     if isinstance(run, dict): return run
# --> 350     with open(run, "r") as f: return json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/marcos/GitHubRepos/FractionalBrownianMotion/src/generative_modelling/resource_logging/trained_rec_ST_1000FTh_PM_MLP_2LFac_NFMRegNSTgt_fBiPot_VPSDE_T256_Ndiff10000_Tdiff1000e+00_DiffEmbSz64_ResLay10_ResChan8_DiffHdnSz64_TrueHybd_TrueWghts_t00_dT3906e-03_025a_-05b_00c_MLP_H4_CUp20_tl110.json.json'
