# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import os
import matplotlib.pyplot as plt
from configs import project_config
from configs.RecursiveVPSDE.LSTM_fMullerBrown.recursive_LSTM_PostMeanScore_MullerBrown_T256_H05_tl_110data import get_config

# %%
num_paths = 10952

# %%
def get_drift_files(config):
    ts_type = f"MullerBrown"
    include = (f"_{num_paths}NPaths_{config.t0}t0_{config.deltaT:.3e}dT_").replace(".", "")
    root_dir = project_config.ROOT_DIR + f"experiments/results/"
    global_files = []
    true_files = []
    local_files = []
    for file in os.listdir(root_dir):
        if "IIDNadaraya" in file and ts_type in file and include in file:
            if "global" in file:
                global_files.append(root_dir+file)
            elif "true" in file:
                true_files.append(root_dir+file)
            elif "local" in file:
                local_files.append(root_dir+file)
    assert len(global_files)>0, "No global files found"
    assert len(true_files)>0, "No true files found"
    assert len(local_files)>0, "No local files found"
    assert (len(global_files) == len(true_files) == len(local_files))
    def extract_bw_number(s):
        match = s.split("/")[-1].split("_")[3][:-2]
        return float("0." + match)
    global_files = sorted(global_files, key=extract_bw_number)
    true_files = sorted(true_files, key=extract_bw_number)
    local_files = sorted(local_files, key=extract_bw_number)
    bws = [extract_bw_number(f) for f in global_files]
    return global_files, true_files, local_files, bws

# %%
config = get_config()
_, true_files, local_files, bws = get_drift_files(config=config)
local_files
# Out:
# ['/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_00001bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0000126bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0000159bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0000201bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0000254bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0000321bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0000405bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0000512bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0000646bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0000816bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_000103bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_00013bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0001642bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0002073bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0002618bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0003305bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0004174bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_000527bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0006654bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0008402bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0010608bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0013394bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0016912bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0021354bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0026963bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0034045bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0042987bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0054277bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0068533bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0086533bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_010926bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0137957bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0174191bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0219942bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0277709bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0350648bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0442745bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0559031bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0705859bw_10952NPaths_00t0_3906e-03dT_local_states.npy',
#  '/Users/marcos/GitHubRepos/FractionalBrownianMotion/experiments/results/IIDNadaraya_fMullerBrown_DriftTrack_0891251bw_10952NPaths_00t0_3906e-03dT_local_states.npy']

# %%
best_rmse = np.inf
toSave = True
i = 0
for file in zip(*[true_files, local_files, bws]):
    bw = file[-1]
    all_true_states = np.load(file[0])/np.sqrt(config.deltaT)
    all_local_states = np.load(file[1])/np.sqrt(config.deltaT)
    assert (len(all_true_states.shape) == len(all_local_states.shape) == 4)
    all_local_errors = np.cumsum(np.mean(np.power(all_true_states- all_local_states,2), axis=(1,3)), axis=-1)/np.arange(1, all_local_states.shape[2]+1)
    total_local_errors = np.mean(np.sqrt(all_local_errors), axis=0)
    total_local_errors_minq = np.quantile(np.sqrt(all_local_errors), axis=0,q=0.025)
    total_local_errors_maxq = np.quantile(np.sqrt(all_local_errors), axis=0,q=0.975)
    print(total_local_errors[-1], (total_local_errors_minq[-1], total_local_errors_maxq[-1]), best_rmse, i)
    i+=1
    if total_local_errors[-1] < best_rmse:
        miny = total_local_errors-total_local_errors_minq
        miny[miny < 0.] = 0.
        maxy = total_local_errors_maxq-total_local_errors
        maxy[maxy < 0.] = 0.
        time_steps = np.linspace(config.t0,config.deltaT*total_local_errors.shape[0],total_local_errors.shape[0])
        best_rmse = total_local_errors[-1]
        fig, ax = plt.subplots(figsize=(14,9))
        ax.scatter(np.linspace(config.t0,config.deltaT*total_local_errors.shape[0],total_local_errors.shape[0]), total_local_errors)
        plt.errorbar(time_steps,total_local_errors,yerr=[miny, maxy],xerr=None, fmt='o', color="blue", alpha=0.4)
        ax.set_title(f"Cumulative RMSE for Nadaraya Estimator", fontsize=40)
        ax.set_ylabel("RMSE", fontsize=38)
        ax.set_xlabel("Time Axis", fontsize=38)
        ax.tick_params(labelsize=38)
        plt.tight_layout()
        if toSave:
            plt.savefig((f"/Users/marcos/Library/CloudStorage/OneDrive-ImperialCollegeLondon/StatML_CDT/Year2/DiffusionModelPresentationImages/IIDNadaraya_fMullerBrown_DriftTrack_{round(bw, 6)}bw").replace(".", "")+".png")
        plt.show()
        plt.close()
        print(f"Final time cumulative RMSE local-time error {total_local_errors[-1]} with IQR {(total_local_errors_minq[-1], total_local_errors_maxq[-1])} at bw {bw}\n")
# Out:
# 2.121591987296573 (2.121591987296573, 2.121591987296573) inf 0
# Final time cumulative RMSE local-time error 2.121591987296573 with IQR (2.121591987296573, 2.121591987296573) at bw 1e-05
#
# 2.121184696740905 (2.1211846967409054, 2.1211846967409054) 2.121591987296573 1
# Final time cumulative RMSE local-time error 2.121184696740905 with IQR (2.1211846967409054, 2.1211846967409054) at bw 1.26e-05
#
# 2.1207112888577293 (2.1207112888577293, 2.1207112888577293) 2.121184696740905 2
# Final time cumulative RMSE local-time error 2.1207112888577293 with IQR (2.1207112888577293, 2.1207112888577293) at bw 1.59e-05
#
# 2.1184154945641334 (2.118415494564134, 2.118415494564134) 2.1207112888577293 3
# Final time cumulative RMSE local-time error 2.1184154945641334 with IQR (2.118415494564134, 2.118415494564134) at bw 2.01e-05
#
# 2.1160098101480633 (2.1160098101480624, 2.1160098101480624) 2.1184154945641334 4
# Final time cumulative RMSE local-time error 2.1160098101480633 with IQR (2.1160098101480624, 2.1160098101480624) at bw 2.54e-05
#
# 2.1146797732568605 (2.1146797732568605, 2.1146797732568605) 2.1160098101480633 5
# Final time cumulative RMSE local-time error 2.1146797732568605 with IQR (2.1146797732568605, 2.1146797732568605) at bw 3.21e-05
#
# 2.1085658770314835 (2.1085658770314843, 2.1085658770314843) 2.1146797732568605 6
# Final time cumulative RMSE local-time error 2.1085658770314835 with IQR (2.1085658770314843, 2.1085658770314843) at bw 4.05e-05
#
# 2.105250582785575 (2.105250582785576, 2.105250582785576) 2.1085658770314835 7
# Final time cumulative RMSE local-time error 2.105250582785575 with IQR (2.105250582785576, 2.105250582785576) at bw 5.12e-05
#
# 2.099521652367296 (2.099521652367296, 2.099521652367296) 2.105250582785575 8
# Final time cumulative RMSE local-time error 2.099521652367296 with IQR (2.099521652367296, 2.099521652367296) at bw 6.46e-05
#
# 2.096719915591095 (2.096719915591095, 2.096719915591095) 2.099521652367296 9
# Final time cumulative RMSE local-time error 2.096719915591095 with IQR (2.096719915591095, 2.096719915591095) at bw 8.16e-05
#
# 2.0860990117238023 (2.086099011723802, 2.086099011723802) 2.096719915591095 10
# Final time cumulative RMSE local-time error 2.0860990117238023 with IQR (2.086099011723802, 2.086099011723802) at bw 0.000103
#
# 2.0761664985424226 (2.0761664985424226, 2.0761664985424226) 2.0860990117238023 11
# Final time cumulative RMSE local-time error 2.0761664985424226 with IQR (2.0761664985424226, 2.0761664985424226) at bw 0.00013
#
# 2.0631999519019213 (2.063199951901921, 2.063199951901921) 2.0761664985424226 12
