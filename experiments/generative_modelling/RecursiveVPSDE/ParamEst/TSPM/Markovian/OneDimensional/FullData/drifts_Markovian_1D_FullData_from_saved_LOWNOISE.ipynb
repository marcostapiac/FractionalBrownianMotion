# %%
# %load_ext autoreload
# %autoreload 2
from configs import project_config
import pickle
import numpy as np
import torch
import os
from src.generative_modelling.models.ClassVPSDEDiffusion import VPSDEDiffusion
import matplotlib.pyplot as plt
from configs.RecursiveVPSDE.Markovian_fQuadSinHF.recursive_Markovian_PostMeanScore_fQuadSinHF2_LowFTh_T256_H05_tl_110data_StbleTgt_LOWNOISE import get_config
#from configs.RecursiveVPSDE.Markovian_fSinLog.recursive_Markovian_PostMeanScore_fSinLog_LowFTh_T256_H05_tl_110data_StbleTgt_LOWNOISE import get_config
#from configs.RecursiveVPSDE.Markovian_fBiPot.recursive_Markovian_PostMeanScore_fBiPot_LowFTh_T256_H05_tl_110data_StbleTgt_LOWNOISE import get_config
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
config = get_config()
assert config.feat_thresh != 1.

#data = np.load(config.data_path, allow_pickle=True).flatten()

#n = (plt.hist(data, bins=200, density=True))
#100*(n[0][(np.abs(n[1])>1.5)[:-1]].sum()/n[0].sum())

# %%
from IPython.core.magic import register_cell_magic

@register_cell_magic
def skip(line, cell):
    return

# %%
def rmse_ignore_nans(y_true, y_pred):
    return np.nanmean((y_true-y_pred)**2)

def plot_drift_estimator(mean, mean_min, mean_max, numpy_Xs, true_drift, Nepoch, dirname, label, toSave: bool = True):
    if "BiPot" in config.data_path:
        ts_type_str = "fBiPot"
    elif "SinLog" in config.data_path:
        ts_type_str = "fSinLog"
    elif "QuadSinHF" in config.data_path:
        ts_type_str = "fQuadSinHF2"
    fig, ax = plt.subplots(figsize=(14, 9))
    ax.scatter(numpy_Xs, true_drift, color="red", label="True Drift")
    ymin = mean - mean_min
    ymax = mean_max - mean
    ymin[ymin < 0.] = 0.
    ymax[ymax < 0.] = 0.
    plt.errorbar(numpy_Xs, mean, yerr=[ymin, ymax], xerr=None, fmt='o', color="blue", alpha=0.4)
    plt.scatter(numpy_Xs, mean, label="Estimated Drift", color="blue")
    ax.set_title(rf"Score Estimator for {label}", fontsize=40)
    ax.tick_params(labelsize=38)
    ax.set_xlabel("State $Y$", fontsize=38)
    ax.set_ylabel("Drift Value", fontsize=38)
    ax.legend(fontsize=24)
    plt.grid(True)
    plt.tight_layout()
    if toSave:
        plt.savefig((root_dir +f"DiffusionModelPresentationImages/TSPM_Markovian/{dirname}/TSPM_MLP_PM_ST_{ts_type_str}_DriftEvalExp_{Nepoch}Nep_{config.loss_factor}LFac").replace(
                ".", "") + ".png", bbox_inches='tight')
    plt.show()
    plt.close()
def plot_ewma_losses(epochs, losses):
    start_idx = 0
    def compute_ema(loss_tensor, beta):
        ema_values = np.zeros_like(loss_tensor)  # Initialize EMA tensor
        ema_values[0] = loss_tensor[0]  # First value stays the same

        for i in range(1, len(loss_tensor)):
            ema_values[i] = beta * ema_values[i - 1] + (1 - beta) * loss_tensor[i]

        return ema_values
    # Define EMA decay rates
    beta_short = 0.9   # Short-term trend (reacts quickly)
    beta_long = 0.92   # Long-term trend (smoother)

    # Compute EMAs
    short_term_ema = compute_ema(losses, beta_short)
    long_term_ema = compute_ema(losses, beta_long)
    plt.scatter(epochs[start_idx:], (short_term_ema[start_idx:]),s=2, label="Short Term Loss")
    print(np.min(short_term_ema[start_idx:]), np.min(long_term_ema[start_idx:]))
    print(long_term_ema[-1])
    plt.yscale("log")
    plt.legend()
    plt.show()
    plt.scatter(epochs[start_idx:], (long_term_ema[start_idx:]),s=2, label="Long Term Loss")
    plt.yscale("log")
    plt.legend()
    plt.show()
    return long_term_ema

# %%
config = get_config()
#assert config.enforce_fourier_mean_reg
root_dir ="/Users/marcos/Library/CloudStorage/OneDrive-ImperialCollegeLondon/StatML_CDT/Year2/DiffusionModels/"

# %%
with open((config.scoreNet_trained_path.replace("/trained_models/", "/training_losses/")+ "_loss"), 'rb') as f:
        losses = (np.array(pickle.load(f)).astype(float))
Nepochs_losses = np.arange(losses.shape[0])
plt.scatter(Nepochs_losses,  losses, s=10, label="Instantaneous Loss")
plt.yscale("log")
plt.legend()
plt.grid(True)
plt.show()
plt.close()
Nepochs_losses[-1]
# Out:
# 5809

# %%
long_term_ema = plot_ewma_losses(epochs=Nepochs_losses, losses=losses)
# Out:
# 7.782893828343588e-05 7.783164862701695e-05
# 7.78425976529774e-05

# %%
best_val_loss = long_term_ema[0]
num_bads = 0
for i in range(long_term_ema.shape[0]):
    if num_bads > 50:
        break
    bad = long_term_ema[i] >= best_val_loss *(1.-1e-3)
    if bad:
        num_bads += 1
        print(i, (1-long_term_ema[i]/best_val_loss)*1e3, num_bads)
    else:
        num_bads = 0
        print(i, (1-long_term_ema[i]/best_val_loss)*1e3)
    if long_term_ema[i] < best_val_loss*(1.-1e-3):
        best_val_loss = long_term_ema[i]
# Out:
# 0 0.0 1
# 1 -11.213154299753114 2
# 2 56.72180327771636
# 3 78.67544580431208
# 4 79.17865421561999
# 5 79.32735458857066
# 6 79.41352565239302
# 7 79.44286530906419
# 8 79.42993382904373
# 9 79.40869490205948
# 10 79.3785610007749
# 11 79.34303349509176
# 12 79.30191425374167
# 13 79.255797885869
# 14 79.20436407664877
# 15 79.14749574400015
# 16 79.08466144522686
# 17 79.0156114494649
# 18 78.94025912457236
# 19 78.85744481834556
# 20 78.76730526280318
# 21 78.66918891464347
# 22 78.56241738382785
# 23 78.44672339729331
# 24 78.31990019883828
# 25 78.18186469975686
# 26 78.03300058621055
# 27 77.87162172744222
# 28 77.69686851952895
# 29 77.50815946459343
# 30 77.30279294025199
# 31 77.08152605158625
# 32 76.84034345828594
# 33 76.5810994371654
# 34 76.30351217536102
# 35 76.00076778996335
# 36 75.6745568607189
# 37 75.32217284084774
# 38 74.94533678344817
# 39 74.54181913354563
# 40 74.10743007910358
# 41 73.64184144271391
# 42 73.14014770832856
# 43 72.60158982000087
# 44 72.03513115314774
# 45 71.4282916108876
# 46 70.77617801385783
# 47 70.08749161334293
# 48 69.34640260812807
# 49 68.5655333889581
# 50 67.73338457133727
# 51 66.84615048592025
# 52 65.91080917958281
# 53 64.94083220613523
# 54 63.93562513847084
# 55 62.84873897431276
# 56 61.70633191372244
# 57 60.52757816103538
# 58 59.28942346135446
# 59 58.007072143674954
# 60 56.672209759114025
# 61 55.255418952442234
# 62 53.79682417816867
# 63 52.370372582417616
# 64 50.89116109889391
# 65 49.33601871291848
# 66 47.78236360666976
# 67 46.251967855935995
# 68 44.7013729416863
# 69 43.10163600400685
# 70 41.4825173367831
# 71 39.80016352240667
# 72 38.18088721521018
# 73 36.56999976130504
# 74 34.92600397495016
# 75 33.3528080012131
# 76 31.714913243435895
# 77 30.102717387605615
# 78 28.564679829596983
# 79 26.96766110865667
# 80 25.402627815010902
# 81 23.892013263666524
# 82 22.472145709944602
# 83 21.56877535691615
# 84 20.68659625290281
# 85 19.37362651298602
# 86 18.198284134707478
# 87 17.10083992120581
# 88 15.937655753432423
# 89 14.954011641068131
# 90 13.877509513271269
# 91 12.95335077775206
# 92 12.197795122679377
# 93 11.058825528145967
# 94 10.059766233961764
# 95 9.42003390073931
# 96 8.756521151272679
# 97 8.502900201430187
# 98 8.318928088977827
# 99 7.426384077101611
# 100 6.653989706055907
# 101 6.283806931629443
# 102 5.842335466987092
# 103 5.575497199732715
# 104 5.263535328372759
# 105 4.62254207757562
# 106 4.277515001745558
# 107 4.066574137602141
# 108 3.7449137687980416
# 109 3.6236178226832783
# 110 3.5289124632453817
# 111 3.066822163727778
# 112 2.1269405882577974
# 113 2.1514120167672734
# 114 2.7037367270167367
# 115 2.577150318180954
# 116 2.182795647235447
# 117 2.029786814437995
# 118 1.8829889124553079
# 119 1.7606961862571824
# 120 1.810896356830738
# 121 1.516847919327824
# 122 1.4511047991320192
# 123 1.2105319867896647
# 124 0.921700885475274 1
# 125 1.662693611755861
# 126 0.1667066872430567 1
# 127 -0.3383828052228033 2
# 128 -0.7560276393863141 3
# 129 -0.15254600974445864 4
# 130 1.1673957814033464
# 131 1.233951461717453
# 132 0.9340771103188983 1
# 133 1.8332211969669387
# 134 0.6176332737202195 1
# 135 0.9913075226113399 2
# 136 1.1769644282315639
# 137 0.21620360288243656 1
# 138 0.5975452147891636 2
# 139 1.1378212340957816
# 140 0.5840194396173892 1
# 141 0.6640068497419938 2
# 142 0.8231249462059553 3
# 143 1.3446778694027328
# 144 0.5574848839474678 1
# 145 0.2112443076610626 2
# 146 -0.41516916165162954 3
# 147 -0.05533277308944484 4
# 148 0.6177472621101687 5
# 149 0.8406978698803913 6
# 150 1.0341921272455368
# 151 0.5834480609993031 1
# 152 1.22050152587172
# 153 0.6733917370125297 1
# 154 1.1421524314199072
# 155 -0.4089099983304312 1
# 156 -0.7363017088817259 2
# 157 -0.47282838800022375 3
# 158 -0.5341107084149144 4
# 159 -1.0707182348987931 5
# 160 -1.096959973841738 6
# 161 -0.4000925201157468 7
# 162 -0.07375407338572337 8
# 163 0.2831906402626094 9
# 164 0.6549224569979417 10
# 165 1.0542238122154268
# 166 0.7378511794273734 1
# 167 1.4559465556965856
# 168 0.7042750794734598 1
# 169 1.1602198689767418
# 170 0.07743684146555019 1
# 171 0.18272582419165406 2
# 172 0.5138607140140472 3
# 173 0.8158812707602658 4
# 174 1.0569590100031334
# 175 -0.22715530149608476 1
# 176 -0.38956530169365067 2
# 177 -0.19702264509269263 3
# 178 -0.5818416373923885 4
# 179 -1.0203082766806482 5
# 180 -1.4113922531080458 6
# 181 -1.4435121020039965 7
# 182 -0.932830266848983 8
# 183 -0.6864834423714328 9
# 184 -1.086922002545787 10
# 185 -1.5283017017386769 11
# 186 -1.202889876427804 12
# 187 -0.6900931666484755 13
# 188 -0.7361105517298405 14
# 189 -1.919360311481766 15
# 190 -3.232492885113958 16
# 191 -3.423710339677255 17
# 192 -3.16124188948419 18
# 193 -3.0677004786185957 19
# 194 -2.9274561327405912 20
# 195 -2.6128923101311763 21
# 196 -2.080109181639367 22
# 197 -1.4415543703918399 23
# 198 -0.8746370940233561 24
# 199 -0.5815923576117932 25
# 200 -1.628189546893699 26
# 201 -3.3835356027918095 27
# 202 -4.540404968808032 28
# 203 -4.537421691456434 29
# 204 -3.8513254146115283 30
# 205 -3.2502826081362013 31
# 206 -2.9096049529047097 32
# 207 -3.4960052033046196 33
# 208 -4.261762515876066 34
# 209 -4.0009767922362105 35
# 210 -3.5539731942828556 36
# 211 -3.3178742968225095 37
# 212 -2.941018599904366 38
# 213 -2.8915795491277763 39
# 214 -3.5034939525702136 40
# 215 -3.9360393439613617 41
# 216 -3.33922635054984 42
# 217 -3.148636021808926 43
# 218 -3.7820660106251403 44
# 219 -3.903268378759206 45
# 220 -3.5066484586872004 46
# 221 -2.9337035967864633 47
# 222 -2.5278106940145317 48
# 223 -2.299146548983222 49
# 224 -2.0595466840762633 50
# 225 -1.9012832918063882 51

# %%
with open((config.scoreNet_trained_path.replace("/trained_models/", "/training_losses/")+ "_loss_LR"), 'rb') as f:
        LRs = (np.array(pickle.load(f)).astype(float))
start = 0
end = -1
plt.scatter(np.arange(LRs.shape[0]),  LRs, s=10, label="Learning Rate")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()
plt.close()

# %%
root_score_dir = ""
if "fQuadSin" in config.data_path:
    minx = -1.5
    assert config.sin_space_scale == 25.
    ts_type = "fQuadSin2"
    include = (f"{config.deltaT:.3e}dT_{config.quad_coeff}a_{config.sin_coeff}b_{config.sin_space_scale}c").replace(
        ".", "")
    root_score_dir = root_dir + f"ExperimentResults/TSPM_Markovian/QuadSinHF2/"
elif "fBiPot" in config.data_path:
    minx = -1.5
    ts_type = "fBiPot"
    include = (f"{config.deltaT:.3e}dT_{config.quartic_coeff}a_{config.quad_coeff}b_{config.const}c").replace(
        ".", "")
    root_score_dir = root_dir + f"ExperimentResults/TSPM_Markovian/BiPot/"
elif "fSinLog" in config.data_path:
    minx = -1.5
    ts_type = "fSinLog"
    include = (f"{config.deltaT:.3e}dT_{config.log_space_scale}b_{config.sin_space_scale}c").replace(
        ".", "")
    root_score_dir = root_dir + f"ExperimentResults/TSPM_Markovian/SinLog/"
#if not config.stable_target:
#    root_score_dir += "NSTgt/"
maxx = -minx

# %%
root_score_dir
# Out:
# '/Users/marcos/Library/CloudStorage/OneDrive-ImperialCollegeLondon/StatML_CDT/Year2/DiffusionModels/ExperimentResults/TSPM_Markovian/QuadSinHF2/'

# %%
NSTgt = "NSTgt" if not config.stable_target else ""
NSTgt += "NFMReg_" if not config.enforce_fourier_mean_reg else ""
if "BiPot" in config.data_path:
    ts_type_str = f"ST_{config.feat_thresh:.3f}FTh_{NSTgt}fBiPot".replace(".", "")
    dirname = "BiPot"
    label = "$\mu_{3}$"
elif "QuadSinHF" in config.data_path:
    ts_type_str = f"ST_{config.feat_thresh:.3f}FTh_{NSTgt}fQuadSinHF".replace(".","")
    dirname = "QuadSinHF"
    label = "$\mu_{2}$"
elif "SinLog" in config.data_path:
    ts_type_str = f"ST_{config.feat_thresh:.3f}FTh_{NSTgt}fSinLog".replace(".","")
    dirname = "SinLog"
    label = "$\mu_{1}$"

# %%
import pandas as pd
root_score_dir = root_dir + f"ExperimentResults/TSPM_Markovian/{dirname}/"
mses=[]
for file in os.listdir(root_score_dir):
    if "MSE" in file and "Diff01" in file:
        print(file)
        mses.append(pd.read_parquet(root_score_dir+file, engine="fastparquet"))
mses = pd.concat(mses).reset_index(drop=False).rename({"index":"epoch"}, axis=1).sort_values("epoch").reset_index(drop=True)
Nepochs_track = mses["epoch"].values.flatten()
# Out:
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_870Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_534Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4695Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4716Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1257Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3438Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2703Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2205Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_312Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_291Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1935Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5388Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2967Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1953Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1659Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4914Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3036Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2445Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1092Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2901Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_672Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_978Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4770Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5280Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1737Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4038Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_399Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_816Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_552Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3855Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5487Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5181Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3492Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4935Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_88Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1695Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5322Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1716Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_65Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4257Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_573Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_837Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3351Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3657Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1038Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1770Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4737Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_333Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5064Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4092Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2946Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4953Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4659Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1914Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_792Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_294Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_159Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4977Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5040Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_279Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_531Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_27Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4215Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4713Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2706Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2685Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3375Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2028Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2760Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3615Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5148Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_813Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_990Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5268Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4911Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1956Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3033Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4455Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2904Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5169Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2247Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_60Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1713Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1215Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_576Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_738Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2925Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5184Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5007Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3012Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1977Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_6Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_336Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_630Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1455Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5061Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2943Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2649Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1911Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4956Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2082Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_195Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_510Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_258Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2727Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3354Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5409Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3099Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4797Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1959Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1653Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4614Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3774Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2307Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2601Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1098Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_678Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_972Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4032Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2865Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_210Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_393Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_558Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_276Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3432Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2547Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_28Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1851Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4995Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2709Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5427Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5121Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1515Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4054Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_897Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_318Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_156Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_450Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5382Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1635Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4374Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2667Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2361Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5406Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5100Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1032Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3957Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3096Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_177Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_471Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_339Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2646Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2340Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4098Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1797Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5220Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4959Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4653Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1614Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4635Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1374Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3498Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_417Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_111Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_594Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_9Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2844Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5166Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5460Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4515Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4851Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1995Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5328Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_579Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_231Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4875Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2022Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5142Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3915Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_396Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_690Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_819Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3039Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4611Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4317Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1656Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1350Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5262Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2604Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3771Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2787Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_135Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_798Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_153Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4371Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4677Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2364Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3717Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_273Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1854Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4719Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2985Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4557Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5124Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_474Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_930Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2949Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2643Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2088Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1317Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1611Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4350Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4656Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_252Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5403Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1875Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3093Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2841Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1557Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5163Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2505Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4854Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1719Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_732Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_234Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2625Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3750Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1677Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1371Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_87Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3018Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_591Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_114Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_954Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2469Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4632Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4938Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5241Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3858Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1992Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1698Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_68Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2001Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3174Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2484Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4512Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4014Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1053Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4197Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4491Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3936Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3597Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2067Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3414Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5349Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4830Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2229Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1035Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1533Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_756Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1296Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2109Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4599Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1014Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1512Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4053Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1491Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1197Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2208Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4992Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4698Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2046Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3435Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_777Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3696Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3390Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3213Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1632Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1938Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5385Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_975Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1599Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2283Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3879Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4296Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2448Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_711Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3894Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2862Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4533Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4035Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2526Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3453Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_49Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1830Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_735Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1218Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2481Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2187Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3477Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3171Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2004Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2502Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4494Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1056Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4011Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3639Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3933Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_951Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3519Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5244Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2622Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2928Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4479Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1293Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2589Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4119Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1458Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3237Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3117Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3411Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# ...
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5043Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2961Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4974Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_918Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_612Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_297Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3138Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4395Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1251Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4710Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_24Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_876Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_699Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_993Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_810Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2763Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2265Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3795Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1731Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5286Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4776Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_42Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_372Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2907Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5025Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3030Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2145Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1359Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_831Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1395Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4251Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_63Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1710Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2742Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2244Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1974Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3192Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5004Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5187Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5481Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3759Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4359Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2940Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_939Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_633Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4731Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1776Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3651Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3357Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2724Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_513Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2700Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3675Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2385Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_21Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1752Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1254Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_537Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_873Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5046Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2964Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5208Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4971Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3555Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_459Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_311Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4155Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1950Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4917Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_219Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_996Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5448Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2766Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3315Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4275Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4773Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1734Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5283Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1971Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5484Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5001Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_834Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_570Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4254Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4752Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_66Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2241Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5469Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1773Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1275Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4734Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5109Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2721Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3654Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_852Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_495Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_516Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_3072Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5229Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_4950Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1917Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_2349Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_1155Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_5067Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_636Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet
# TSPM_MLP_ST_0002FTh_NSTgtNFMReg_fQuadSinHF_DriftEvalExp_330Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_Diff01_muhats_MSE.parquet

# %%
common_epochs = np.intersect1d(Nepochs_losses, Nepochs_track)
common_epochs = np.intersect1d(common_epochs, np.arange(400, 8000))
start_idx = 0
common_epochs = common_epochs[start_idx:]
losses_idx = np.unique([np.argwhere(c == Nepochs_losses)[0,0] for c in common_epochs])
track_idx = np.unique([np.argwhere(c == Nepochs_track)[0,0] for c in common_epochs])
red_losses = losses[losses_idx]
print(track_idx.shape, common_epochs.shape)
#track_rmses = np.array(list(drift_track_rmses.values()))[track_idx]
track_rmses = mses.iloc[track_idx,:].mse.values.flatten()
eval_rmses = track_rmses
print(track_rmses.shape, common_epochs.shape)
# Out:
# (1704,) (1704,)
# (1704,) (1704,)

# %%
toSave = False
fig, ax = plt.subplots(figsize=(14,9))
sc1 = ax.scatter(common_epochs, red_losses, s=10, label="Training Loss")
ax.tick_params(axis="both",labelsize=24)
ax2 = ax.twinx()
sc2 = ax2.scatter(common_epochs, eval_rmses, s=20, color="orange",label="Domain MSE")
ax.set_xlabel("Training Epochs", fontsize=38)
ax.set_title(rf"Losses for StableTarget {label}", fontsize=40)
ax.tick_params(axis="both",labelsize=24)
ax2.tick_params(axis="both",labelsize=24)
plt.tight_layout()
handles = [sc1, sc2]
labels = [h.get_label() for h in handles]
ax.legend(handles, labels, fontsize=24)
if toSave:
    plt.savefig((root_dir +f"DiffusionModelPresentationImages/TSPM_Markovian/{dirname}/TSPM_MLP_PM_ST_{config.feat_thresh:.3f}FTh_{ts_type}_LossesEvalExp_{config.loss_factor}LFac").replace(".","")+".png",  bbox_inches='tight')
plt.grid(True)
plt.show()
plt.close()
fig, ax = plt.subplots(figsize=(14,9))
sc1 = ax.scatter(common_epochs, red_losses, s=10, label="Training Loss")
ax2 = ax.twinx()
sc2 = ax2.scatter(common_epochs, track_rmses, s=20, color="red",label="Tracking MSE")
ax.set_xlabel("Training Epochs", fontsize=38)
ax.set_title(rf"Losses for StableTarget {label}", fontsize=40)
ax.tick_params(axis="both",labelsize=24)
ax2.tick_params(axis="both",labelsize=24)
plt.tight_layout()
handles = [sc1, sc2]
labels = [h.get_label() for h in handles]
# Add a single legend on ax1
ax.legend(handles, labels, fontsize=24)
if toSave:
    plt.savefig((root_dir + f"DiffusionModelPresentationImages/TSPM_Markovian/{dirname}/TSPM_MLP_PM_ST_{config.feat_thresh:.3f}FTh_{ts_type}_LossesTrack_{config.loss_factor}LFac").replace(".","")+".png",  bbox_inches='tight')
plt.grid(True)
plt.show()
plt.close()
print(mses)
# Out:
#       epoch         mse
# 0         1  732.945045
# 1         2   21.521111
# 2         3    2.061641
# 3         4    1.980144
# 4         5    1.353451
# ...     ...         ...
# 1872   5478    0.003465
# 1873   5481    0.005467
# 1874   5484    0.006258
# 1875   5487    0.003269
# 1876   5490    0.004547
#
# [1877 rows x 2 columns]

# %%
print(mses.iloc[np.argmin(mses.mse),:])
# Out:
# epoch    5425.000000
# mse         0.002029
# Name: 1854, dtype: float64

# %%
raise RuntimeError
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 raise RuntimeError
#
# RuntimeError:

# %%
best_rmse = np.inf
m_mu_hats = []
toSave = True
for f in zip(*[common_epochs, driftevalexp_files]):
    print(f)
    Nepoch = f[0]
    file = f[1]
    if Nepoch not in common_epochs: continue
    if Nepoch != best_epoch_eval: continue
    try:
        muhats = torch.Tensor(np.load(file, allow_pickle=True))
        Xshape = muhats.shape[0]
        Xs = torch.Tensor(np.linspace(-1.5,1.5,Xshape))
        if "BiPot" in config.data_path:
            true_drifts = -(4.*config.quartic_coeff * np.power(Xs, 3) + 2.*config.quad_coeff * Xs + config.const).numpy()
        elif "QuadSin" in config.data_path:
            true_drifts = (-2. * config.quad_coeff * Xs + config.sin_coeff * config.sin_space_scale * np.sin(
        config.sin_space_scale * Xs)).numpy()
        elif "SinLog" in config.data_path:
            true_drifts = (-np.sin(config.sin_space_scale*Xs)*np.log(1+config.log_space_scale*np.abs(Xs))/config.sin_space_scale).numpy()
        #print(Nepoch, muhats.shape, true_drifts.shape)
        muhats = muhats[:, -1, :].reshape(muhats.shape[0], muhats.shape[2]*1)
        print(muhats.shape)
        mu_hats = muhats.mean(dim=-1).numpy()
        rmse = rmse_ignore_nans(true_drifts, mu_hats).astype(np.float64)
        print(rmse)
        if rmse < best_rmse:
            print(muhats.shape)
            mu_hats_minq = muhats.quantile(dim=-1, q=0.005).numpy() # Lower bound
            mu_hats_maxq = muhats.quantile(dim=-1, q=0.995).numpy() # Upper boun
            best_rmse = rmse
            print(mu_hats_maxq.shape)
            plot_drift_estimator(mean=mu_hats, mean_min=mu_hats_minq, mean_max=mu_hats_maxq, dirname=dirname, numpy_Xs=Xs.numpy(),  toSave=toSave, true_drift=true_drifts, Nepoch=Nepoch, label=label)
            print(f"MSE {rmse} at Nepoch {Nepoch}\n")
            print(file)
    except FileNotFoundError as e:
        print(f"{e}, Hi")
#m_mu_hats = torch.Tensor(np.array(m_mu_hats))
#m_mu_hats = m_mu_hats.numpy()
#mu_hats = m_mu_hats.mean(axis=0)

# %%
curr_rmse = np.inf
toSave = False
i = 0
for file in zip(*[driftoostrack_true_files, driftoostrack_local_files, common_epochs]):
    Nepoch = file[-1]
    all_true_states = np.load(file[0])
    all_local_states = np.load(file[1])
    if Nepoch != best_epoch_track:
        continue
    print(Nepoch, file)
    if (len(all_true_states.shape) == len(all_local_states.shape) == 4):
        time_steps = np.linspace(config.t0,config.deltaT*all_true_states.shape[2],all_true_states.shape[2])
        all_local_errors = np.sum(np.power(all_true_states- all_local_states,2), axis=-1)
        all_local_errors = all_local_errors.reshape(-1, all_local_errors.shape[-1])
        total_local_errors = np.sqrt(np.mean((all_local_errors), axis=0))/np.sqrt(time_steps)
        all_errs = np.sqrt(all_local_errors)/np.sqrt(time_steps)
        total_local_errors[np.isinf(total_local_errors)] = 0.
        all_errs[np.isinf(all_errs)] = 0.
        total_local_errors_minq, total_local_errors_maxq = np.quantile(all_errs, axis=0,q=[0.005,0.995])
        i += 1
        if total_local_errors[-1]  < curr_rmse:
            curr_rmse = total_local_errors[-1]
            fig, ax = plt.subplots(figsize=(14,9))
            plt.grid(True)
            ax.scatter(time_steps, total_local_errors)
            plt.fill_between(time_steps,y1=total_local_errors_minq, y2=total_local_errors_maxq, color="blue", alpha=0.4)
            ax.set_title(f"Pathwise RMSE for Score Estimator for {label}",fontsize=40)

            ax.set_xlabel("Time Axis", fontsize=38)
            ax.tick_params(labelsize=38)

            fig.canvas.draw()
            # Get the offset text (e.g., '1e-5')
            offset_text = ax.yaxis.get_offset_text().get_text()

            # Remove the offset text from the axis
            ax.yaxis.get_offset_text().set_visible(False)

            # Inject the scale into the y-axis label
            if offset_text:
                ax.set_ylabel(f'RMSE ({offset_text})', fontsize=38)
            else:
                ax.set_ylabel('RMSE', fontsize=38)
            plt.tight_layout()
            if toSave:
                plt.savefig((root_dir +f"DiffusionModelPresentationImages/TSPM_Markovian/{dirname}/TSPM_MLP_PM_ST_{config.feat_thresh:.3f}FTh_{ts_type}_DriftTrack_{Nepoch}Nep_{round(total_local_errors_minq[-1], 7)}_MinIQR_{round(total_local_errors_maxq[-1], 7)}_MaxIQR").replace(".", "")+".png")
            plt.grid(True)
            plt.show()
            plt.close()
            print(f"Final time cumulative MSE local-time error {total_local_errors[-1]} with IQR ({total_local_errors_minq[-1], total_local_errors_maxq[-1]})at Nepoch {Nepoch}\n")
            print(file)
