# %%
import numpy as np
import os
import matplotlib.pyplot as plt
from configs import project_config

# %%
num_paths = 1024
save_path = (
            project_config.ROOT_DIR + f"experiments/results/8DLnz_NewDriftEvalExp_MSEs_{num_paths}NPaths").replace(
    ".", "")
all_true_paths=np.load(save_path+"_true_paths.pickle.npy", allow_pickle=True)
all_score_paths=np.load(save_path+"_score_paths.pickle.npy", allow_pickle=True)
all_nad_paths=np.load(save_path+"_nad_paths.pickle.npy", allow_pickle=True)
is_prevPath_obs=np.load(save_path+"_trainingPrevPath_paths.pickle.npy", allow_pickle=True)

# %%
all_true_paths.shape
# Out:
# (1, 1000, 3, 8)

# %%
is_prevPath_obs.shape
# Out:
# (1024, 255, 8)
