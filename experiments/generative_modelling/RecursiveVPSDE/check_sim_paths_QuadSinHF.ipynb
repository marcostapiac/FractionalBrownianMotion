# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
from configs.RecursiveVPSDE.Markovian_fQuadSinHF.recursive_Markovian_PostMeanScore_fQuadSinHF2_LowFTh_T256_H05_tl_110data_StbleTgt import get_config

# %%
score = np.load('/Users/marcos/Library/CloudStorage/OneDrive-ImperialCollegeLondon/StatML_CDT/Year2/DiffusionModels/ExperimentResults/TSPM_Markovian/QuadSinHF2/TSPM_MLP_ST_0002FTh_fQuadSinHF_OOSDriftTrack_364Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_global_states.npy').reshape((200, 257, 1))

# %%
hermite = np.load('/Users/marcos/Library/CloudStorage/OneDrive-ImperialCollegeLondon/StatML_CDT/Year2/DiffusionModels/ExperimentResults/Hermite/QuadSinHF2/Hermite_fQuadSinHF_DriftTrack_7R_10240NPaths_00t0_3906e-03dT_05a_004b_250c_256NumDPS_global_states.npy').reshape((200, 257, 1))

# %%
nadaraya = np.load('/Users/marcos/Library/CloudStorage/OneDrive-ImperialCollegeLondon/StatML_CDT/Year2/DiffusionModels/ExperimentResults/Nadaraya/QuadSinHF2/IIDNadaraya_fQuadSinHF_DriftTrack_0018211bw_10240NPaths_00t0_3906e-03dT_05a_004b_250c_256NumDPS_global_states.npy').reshape((200, 257, 1))

# %%
true_paths = np.load('/Users/marcos/Library/CloudStorage/OneDrive-ImperialCollegeLondon/StatML_CDT/Year2/DiffusionModels/ExperimentResults/TSPM_Markovian/QuadSinHF2/TSPM_MLP_ST_0002FTh_fQuadSinHF_OOSDriftTrack_364Nep_00t0_3906e-03dT_05a_004b_250c_10ResLay_2LFac_BetaMax20e+01_true_states.npy').reshape((200, 257, 1))

# %%
for t in range(0,score.shape[1], 50):
    plt.hist(score[:, t, 0], bins=50, label="Score")
    plt.hist(hermite[:, t, 0], bins=50, label="Hermite")
    plt.hist(true_paths[:, t, 0], bins=50, label="True")
    plt.legend()
    plt.show()
    plt.close()
