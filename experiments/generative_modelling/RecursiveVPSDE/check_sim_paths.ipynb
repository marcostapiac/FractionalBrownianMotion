# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = np.load("/Users/marcos/GitHubRepos/FractionalBrownianMotion/data/fBiPot_8DDims_samples_t00_dT3906e-03_T256_025a_-20b_00c_40Diff_00Init.npy")
for d in range(0,data.shape[2]):
    plt.hist(data[:, :, d].flatten(), bins=150, density=True)
plt.show()
plt.close()
sns.heatmap(np.corrcoef(data.reshape(-1, data.shape[-1]).T))
plt.show()
plt.close()

# %%
data = np.load("/Users/marcos/GitHubRepos/FractionalBrownianMotion/data/fBiPot_8DDimsNS_samples_t00_dT3906e-03_T256_025a_-20b_00c_20coup_40Diff_00Init.npy")
for d in range(0,data.shape[2]):
    plt.hist(data[:, :, d].flatten(), bins=150, density=True)
plt.show()
plt.close()
sns.heatmap(np.corrcoef(data.reshape(-1, data.shape[-1]).T))
plt.show()
plt.close()

# %%
data = np.load("/Users/marcos/GitHubRepos/FractionalBrownianMotion/data/fBiPot_8DDimsNS_samples_t00_dT3906e-03_T256_025a_-20b_00c_20coup_40Diff_00Init.npy")
for d in range(0,data.shape[2]):
    plt.hist(data[:, :, d].flatten(), bins=150, density=True)
plt.show()
plt.close()
sns.heatmap(np.corrcoef(data.reshape(-1, data.shape[-1]).T))
plt.show()
plt.close()

# %%
v = np.random.normal(size=12)
v = v / np.linalg.norm(v)
print(np.array(v))
# Out:
# [-0.17307135  0.18174567 -0.26785012 -0.15083465  0.25216444  0.45399956
#  -0.01937965  0.15461691 -0.34995137 -0.328612    0.36020681  0.4339756 ]

# %%
v12=np.array([-0.17307135 , 0.18174567, -0.26785012, -0.15083465,  0.25216444 , 0.45399956,
 -0.01937965 , 0.15461691, -0.34995137, -0.328612   , 0.36020681,  0.4339756 ])

# %%
v8=np.array([-0.046785, -0.352242, 0.263607,-0.761998, -0.096162, 0.190698 ,-0.071474, -0.415797])
